# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow import keras
import einops
from tensorflow.keras.models import load_model
from tensorflow.keras.losses import SparseCategoricalCrossentropy
# 启用 XLA
tf.config.optimizer.set_jit(True)
TARGET_FRAMES = 20  # 每个视频的关键帧数
HEIGHT, WIDTH = 224, 224  # 每帧的大小
class Conv2Plus1D(layers.Layer):
    def __init__(self, filters, kernel_size, padding, **kwargs):
        super().__init__(**kwargs)
        self.filters = filters
        self.kernel_size = kernel_size
        self.padding = padding
        self.seq = tf.keras.Sequential([
            layers.Conv3D(filters=filters, kernel_size=(1, kernel_size[1], kernel_size[2]), padding=padding),
            layers.Conv3D(filters=filters, kernel_size=(kernel_size[0], 1, 1), padding=padding)
        ])

    def call(self, x):
        return self.seq(x)

    def get_config(self):
        # 确保返回所有参数，包括自定义的
        config = super().get_config()
        config.update({
            'filters': self.filters,
            'kernel_size': self.kernel_size,
            'padding': self.padding
        })
        return config

    @classmethod
    def from_config(cls, config):
        # 通过从配置字典中解构来创建类实例
        return cls(**config)

class ResidualMain(layers.Layer):
    def __init__(self, filters, kernel_size, **kwargs):
        super().__init__(**kwargs)
        self.filters = filters
        self.kernel_size = kernel_size
        self.seq = tf.keras.Sequential([
            Conv2Plus1D(filters=filters, kernel_size=kernel_size, padding='same'),
            layers.LayerNormalization(),
            layers.ReLU(),
            Conv2Plus1D(filters=filters, kernel_size=kernel_size, padding='same'),
            layers.LayerNormalization()
        ])

    def call(self, x):
        return self.seq(x)

    def get_config(self):
        config = super().get_config()
        config.update({
            'filters': self.filters,
            'kernel_size': self.kernel_size
        })
        return config

    @classmethod
    def from_config(cls, config):
        return cls(**config)

def add_residual_block(input, filters, kernel_size):
  """
    Add residual blocks to the model. If the last dimensions of the input data
    and filter size does not match, project it such that last dimension matches.
  """
  out = ResidualMain(filters, 
                     kernel_size)(input)

  res = input
  # Using the Keras functional APIs, project the last dimension of the tensor to
  # match the new filter size
  if out.shape[-1] != input.shape[-1]:
    res = Project(out.shape[-1])(res)

  return layers.add([res, out])


class Project(layers.Layer):
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.seq = tf.keras.Sequential([
            layers.Dense(units),
            layers.LayerNormalization()
        ])

    def call(self, x):
        return self.seq(x)

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units
        })
        return config

    @classmethod
    def from_config(cls, config):
        return cls(**config)


class ResizeVideo(layers.Layer):
    def __init__(self, height, width, **kwargs):
        super().__init__(**kwargs)
        self.height = height
        self.width = width
        self.resizing_layer = layers.Resizing(self.height, self.width)

    def call(self, video):
        old_shape = einops.parse_shape(video, 'b t h w c')
        images = einops.rearrange(video, 'b t h w c -> (b t) h w c')
        images = self.resizing_layer(images)
        videos = einops.rearrange(images, '(b t) h w c -> b t h w c', t=old_shape['t'])
        return videos

    def get_config(self):
        config = super().get_config()
        config.update({
            'height': self.height,
            'width': self.width
        })
        return config

    @classmethod
    def from_config(cls, config):
        return cls(**config)

input_shape = (None, 20, HEIGHT, WIDTH, 3)  # 输入视频的形状，None 表示批次大小不固定
input = layers.Input(shape=(input_shape[1:]))  # 定义输入层，形状为 (时间步数, 高度, 宽度, 通道数)
x = input

# 初始卷积层：执行 2+1D 卷积操作（空间 + 时间分解）
x = Conv2Plus1D(filters=16, kernel_size=(3, 7, 7), padding='same')(x)
x = layers.BatchNormalization()(x)  # 批量归一化层，规范化每批次的特征
x = layers.ReLU()(x)  # 激活函数 ReLU
x = ResizeVideo(HEIGHT//2, WIDTH//4 )(x)  # 调整视频帧的尺寸到 (HEIGHT/2, WIDTH/2)

# Block 1: 添加第一个残差块并调整尺寸
x = add_residual_block(x, 16, (3, 3, 3))  # 添加残差块，过滤器数为 16，卷积核大小为 3x3x3
x = ResizeVideo(HEIGHT // 4, WIDTH // 4)(x)  # 调整尺寸到 (HEIGHT/4, WIDTH/4)

# Block 2: 添加第二个残差块并调整尺寸
x = add_residual_block(x, 32, (3, 3, 3))  # 过滤器数为 32
x = ResizeVideo(HEIGHT // 8, WIDTH // 8)(x)  # 调整尺寸到 (HEIGHT/8, WIDTH/8)

# Block 3: 添加第三个残差块并调整尺寸
x = add_residual_block(x, 64, (3, 3, 3))  # 过滤器数为 64
x = ResizeVideo(HEIGHT // 16, WIDTH // 16)(x)  # 调整尺寸到 (HEIGHT/16, WIDTH/16)

# Block 4: 添加第四个残差块
x = add_residual_block(x, 128, (3, 3, 3))  # 过滤器数为 128

# 全局平均池化和分类
x = layers.GlobalAveragePooling3D()(x)  # 对时间、空间维度进行全局平均池化，生成特征向量
x = layers.Flatten()(x)  # 展平为 1D 向量
x = layers.Dense(15)(x)  # 全连接层输出 10 个分类

# 定义模型
model = keras.Model(input, x)
# 修改损失函数的 reduction 参数
loss = SparseCategoricalCrossentropy(from_logits=False, reduction='sum_over_batch_size')
# 使用 Keras 提供的工具绘制模型结构
keras.utils.plot_model(
    model,               # 目标模型
    expand_nested=True,  # 展开嵌套的层，例如子模块或自定义层
    dpi=60,              # 设置图片分辨率
    show_shapes=True     # 显示每一层输出的形状
)



# 加载模型函数
def load_my_model(model_path):
    # 定义自定义层
    custom_objects = {
        'Conv2Plus1D': Conv2Plus1D,
        'ResizeVideo': ResizeVideo,
        'ResidualMain': ResidualMain,
        'Project': Project  # 确保 Project 也被添加到 custom_objects 中
    }
    
    # 使用 Keras 加载模型
    model = load_model(model_path, custom_objects=custom_objects)
    
    # 编译模型
    model.compile(
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=False),
        optimizer=keras.optimizers.Adam(learning_rate=0.0001),
        metrics=['accuracy']
    )
    
    return model
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
# 调用加载模型的函数，假设您给的路径是 model_path
model_path = r'C:\data\result\model\200grey_model.h5'  # 替换为您实际的模型文件路径
model = load_my_model(model_path)

# %%
import os
import numpy as np
import tensorflow as tf
from PIL import Image

def sobel_custom(image_array):
    sobel_x = np.array([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]])
    sobel_y = np.array([[-1, -2, -1], [0, 0, 0], [1, 2, 1]])
    
    grad_x = np.zeros_like(image_array)
    grad_y = np.zeros_like(image_array)
    
    height, width = image_array.shape
    
    for i in range(1, height-1):
        for j in range(1, width-1):
            grad_x[i, j] = np.sum(image_array[i-1:i+2, j-1:j+2] * sobel_x)
            grad_y[i, j] = np.sum(image_array[i-1:i+2, j-1:j+2] * sobel_y)
    
    return grad_x, grad_y

def load_and_preprocess_frames_custom(frame_paths, target_height, target_width, target_frames):
    frames = []
    for frame_path in sorted(frame_paths):
        image = Image.open(frame_path).convert('L')  # 转为灰度图
        image = image.resize((target_width, target_height))
        image_array = np.array(image, dtype=np.float32) / 255.0
        
        grad_x, grad_y = sobel_custom(image_array)
        
        grad_x = (grad_x - grad_x.min()) / (grad_x.max() - grad_x.min() + 1e-6)
        grad_y = (grad_y - grad_y.min()) / (grad_y.max() - grad_y.min() + 1e-6)
        
        three_channel_frame = np.stack([image_array, grad_x, grad_y], axis=-1)
        frames.append(three_channel_frame)

    if len(frames) > target_frames:
        frames = frames[:target_frames]
    elif len(frames) < target_frames:
        padding = target_frames - len(frames)
        padding_frame = np.zeros((target_height, target_width, 3))
        frames.extend([padding_frame] * padding)

    return np.stack(frames, axis=0)

def predict_from_folder_custom(model, folder_path, height, width, frames):
    frame_paths = sorted([
        os.path.join(folder_path, frame).replace("\\", "/")
        for frame in os.listdir(folder_path)
        if frame.endswith((".jpg", ".png"))
    ])
    
    if not frame_paths:
        raise ValueError(f"文件夹 {folder_path} 中没有找到帧文件！")
    
    processed_frames = load_and_preprocess_frames_custom(frame_paths, height, width, frames)
    processed_frames = np.expand_dims(processed_frames, axis=0)

    probabilities = model.predict(processed_frames)
    return probabilities

def create_dataset_with_predictions_custom(model, output_dir, video_dir, height, width, frames):
    data_list = []
    labels_list = []

    for folder_name in os.listdir(output_dir):
        folder_path = os.path.join(output_dir, folder_name).replace("\\", "/")
        if not os.path.isdir(folder_path):
            continue

        for reference_folder in os.listdir(folder_path):
            reference_folder_path = os.path.join(folder_path, reference_folder).replace("\\", "/")
            if not os.path.isdir(reference_folder_path):
                continue

            # 提取父文件夹名称（如 0-两手托天理三焦（八段锦））
            parent_folder_name = folder_name.split("\\")[-1]
            
            # 查找对应的 MP4 文件路径
            video_folder_path = os.path.join(video_dir, parent_folder_name)
            if not os.path.isdir(video_folder_path):
                print(f"未找到视频文件夹：{video_folder_path}")
                continue
            
            video_files = [
                f for f in os.listdir(video_folder_path) if f.endswith(".mp4")
            ]
            if not video_files:
                print(f"在 {video_folder_path} 中没有找到视频文件")
                continue
            
            # 假设文件名格式为 reference_0_0.871667.mp4，提取标签
            video_file = video_files[0]
            try:
                label = float(video_file.split("_")[-1].replace(".mp4", ""))
            except ValueError:
                print(f"文件名中未找到分数标签: {video_file}")
                continue

            try:
                probabilities = predict_from_folder_custom(model, reference_folder_path, height, width, frames)
            except ValueError as e:
                print(e)
                continue

            data_list.append(probabilities[0])
            labels_list.append(label)

    data_tensor = tf.convert_to_tensor(np.array(data_list), dtype=tf.float32)
    labels_tensor = tf.convert_to_tensor(np.array(labels_list), dtype=tf.float32)
    return tf.data.Dataset.from_tensor_slices((data_tensor, labels_tensor))

# 参数配置
OUTPUT_DIR = "C:/data/result/scene_detector"  # 关键帧存放目录
VIDEO_DIR = "C:/data/video"  # 原视频文件目录
HEIGHT, WIDTH = 224, 224  # 每帧的大小
FRAMES = 20  # 每个视频的关键帧数
MODEL = model  # 加载您的 TensorFlow 模型

# 构建数据集
dataset = create_dataset_with_predictions_custom(MODEL, OUTPUT_DIR, VIDEO_DIR, HEIGHT, WIDTH, FRAMES)

# 检查数据集
for data, label in dataset.take(1):
    print("数据向量 (1×14):", data.numpy())
    print("标签值:", label.numpy())
# Out:
# 1/1 [==============================] - 16s 16s/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 文件夹 C:/data/result/scene_detector/0-两手托天理三焦（八段锦）/动作0-10-31 中没有找到帧文件！
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 121
#     118 MODEL = model  # 加载您的 TensorFlow 模型
#     120 # 构建数据集
# --> 121 dataset = create_dataset_with_predictions_custom(MODEL, OUTPUT_DIR, VIDEO_DIR, HEIGHT, WIDTH, FRAMES)
#     123 # 检查数据集
#     124 for data, label in dataset.take(1):
#
# Cell In[6], line 101, in create_dataset_with_predictions_custom(model, output_dir, video_dir, height, width, frames)
#      98     continue
#     100 try:
# --> 101     probabilities = predict_from_folder_custom(model, reference_folder_path, height, width, frames)
#     102 except ValueError as e:
#     103     print(e)
#
# Cell In[6], line 56, in predict_from_folder_custom(model, folder_path, height, width, frames)
#      53 if not frame_paths:
#      54     raise ValueError(f"文件夹 {folder_path} 中没有找到帧文件！")
# ---> 56 processed_frames = load_and_preprocess_frames_custom(frame_paths, height, width, frames)
#      57 processed_frames = np.expand_dims(processed_frames, axis=0)
#      59 probabilities = model.predict(processed_frames)
#
# Cell In[6], line 29, in load_and_preprocess_frames_custom(frame_paths, target_height, target_width, target_frames)
#      26 image = image.resize((target_width, target_height))
#      27 image_array = np.array(image, dtype=np.float32) / 255.0
# ---> 29 grad_x, grad_y = sobel_custom(image_array)
#      31 grad_x = (grad_x - grad_x.min()) / (grad_x.max() - grad_x.min() + 1e-6)
#      32 grad_y = (grad_y - grad_y.min()) / (grad_y.max() - grad_y.min() + 1e-6)
#
# Cell In[6], line 18, in sobel_custom(image_array)
#      16     for j in range(1, width-1):
#      17         grad_x[i, j] = np.sum(image_array[i-1:i+2, j-1:j+2] * sobel_x)
# ---> 18         grad_y[i, j] = np.sum(image_array[i-1:i+2, j-1:j+2] * sobel_y)
#      20 return grad_x, grad_y
#
# File <__array_function__ internals>:2, in sum(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
import os 
import numpy as np
import tensorflow as tf
from PIL import Image

def sobel_custom(image_array):
    sobel_x = np.array([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]])
    sobel_y = np.array([[-1, -2, -1], [0, 0, 0], [1, 2, 1]])
    
    grad_x = np.zeros_like(image_array)
    grad_y = np.zeros_like(image_array)
    
    height, width = image_array.shape
    
    for i in range(1, height-1):
        for j in range(1, width-1):
            grad_x[i, j] = np.sum(image_array[i-1:i+2, j-1:j+2] * sobel_x)
            grad_y[i, j] = np.sum(image_array[i-1:i+2, j-1:j+2] * sobel_y)
    
    return grad_x, grad_y

def load_and_preprocess_frames_custom(frame_paths, target_height, target_width, target_frames):
    frames = []
    for frame_path in sorted(frame_paths):
        image = Image.open(frame_path).convert('L')  # 转为灰度图
        image = image.resize((target_width, target_height))
        image_array = np.array(image, dtype=np.float32) / 255.0
        
        grad_x, grad_y = sobel_custom(image_array)
        
        grad_x = (grad_x - grad_x.min()) / (grad_x.max() - grad_x.min() + 1e-6)
        grad_y = (grad_y - grad_y.min()) / (grad_y.max() - grad_y.min() + 1e-6)
        
        three_channel_frame = np.stack([image_array, grad_x, grad_y], axis=-1)
        frames.append(three_channel_frame)

    if len(frames) > target_frames:
        frames = frames[:target_frames]
    elif len(frames) < target_frames:
        padding = target_frames - len(frames)
        padding_frame = np.zeros((target_height, target_width, 3))
        frames.extend([padding_frame] * padding)

    return np.stack(frames, axis=0)

def predict_from_folder_custom(model, folder_path, height, width, frames):
    frame_paths = sorted([os.path.join(folder_path, frame).replace("\\", "/") for frame in os.listdir(folder_path) if frame.endswith((".jpg", ".png"))])
    
    if not frame_paths:
        raise ValueError(f"文件夹 {folder_path} 中没有找到帧文件！")
    
    processed_frames = load_and_preprocess_frames_custom(frame_paths, height, width, frames)
    processed_frames = np.expand_dims(processed_frames, axis=0)

    probabilities = model.predict(processed_frames)
    return probabilities

def create_dataset_with_predictions_custom(model, output_dir, video_dir, height, width, frames, log_file_path):
    data_list = []
    labels_list = []
    
    # 打开日志文件进行写入
    with open(log_file_path, 'a') as log_file:

        for folder_name in os.listdir(output_dir):
            folder_path = os.path.join(output_dir, folder_name).replace("\\", "/")
            if not os.path.isdir(folder_path):
                continue

            for reference_folder in os.listdir(folder_path):
                reference_folder_path = os.path.join(folder_path, reference_folder).replace("\\", "/")
                if not os.path.isdir(reference_folder_path):
                    continue

                # 提取父文件夹名称（如 0-两手托天理三焦（八段锦））
                parent_folder_name = folder_name.split("\\")[-1]
                
                # 查找对应的 MP4 文件路径
                video_folder_path = os.path.join(video_dir, parent_folder_name)
                if not os.path.isdir(video_folder_path):
                    print(f"未找到视频文件夹：{video_folder_path}")
                    continue
                
                video_files = [f for f in os.listdir(video_folder_path) if f.endswith(".mp4")]
                if not video_files:
                    print(f"在 {video_folder_path} 中没有找到视频文件")
                    continue
                
                # 假设文件名格式为 reference_0_0.871667.mp4，提取标签
                video_file = video_files[0]
                try:
                    label = float(video_file.split("_")[-1].replace(".mp4", ""))
                except ValueError:
                    print(f"文件名中未找到分数标签: {video_file}")
                    continue

                try:
                    probabilities = predict_from_folder_custom(model, reference_folder_path, height, width, frames)
                except ValueError as e:
                    print(e)
                    continue

                data_list.append(probabilities[0])
                labels_list.append(label)

                # 记录日志到文件（包括标签和预测结果）
                log_file.write(f"{parent_folder_name}_{reference_folder} (标签: {label})\n")  # 写入文件夹名和标签
                log_file.write(" ".join(map(str, probabilities[0])) + "\n")  # 写入14个概率值

    data_tensor = tf.convert_to_tensor(np.array(data_list), dtype=tf.float32)
    labels_tensor = tf.convert_to_tensor(np.array(labels_list), dtype=tf.float32)
    return tf.data.Dataset.from_tensor_slices((data_tensor, labels_tensor))

# 参数配置
OUTPUT_DIR = "C:/data/result/scene_detector"  # 关键帧存放目录
VIDEO_DIR = "C:/data/video"  # 原视频文件目录
LOG_FILE_PATH = "C:/data/result/txt/predictions_log.txt"  # 预测结果日志文件路径
HEIGHT, WIDTH = 224, 224  # 每帧的大小
FRAMES = 20  # 每个视频的关键帧数
MODEL = model  # 加载您的 TensorFlow 模型

# 构建数据集
dataset = create_dataset_with_predictions_custom(MODEL, OUTPUT_DIR, VIDEO_DIR, HEIGHT, WIDTH, FRAMES, LOG_FILE_PATH)

# 检查数据集
for data, label in dataset.take(1):
    print("数据向量 (1×14):", data.numpy())
    print("标签值:", label.numpy())
# Out:
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 文件夹 C:/data/result/scene_detector/0-两手托天理三焦（八段锦）/动作0-10-31 中没有找到帧文件！
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 数据向量 (1×14): [9.95986879e-01 8.18129047e-06 8.77484126e-06 5.78877994e-08
#  4.54797510e-06 3.13687133e-06 4.72669015e-09 9.77272401e-04
#  1.68164005e-03 1.30030964e-09 1.32916577e-03 6.90987578e-09
#  3.64507400e-07 1.03542185e-07]
# 标签值: 0.871667

# %%
import os
import numpy as np
import tensorflow as tf

# 文件路径
log_file = r"C:\data\result\txt\predictions_log.txt"
video_base_path = r"C:\data\video"

# 初始化特征和标签列表
features, labels = [], []

# 读取文件并解析数据
with open(log_file, "r", encoding="utf-8") as f:
    lines = f.readlines()

i = 0
while i < len(lines) - 1:  # 遍历文件
    label_line = lines[i].strip()
    data_line = lines[i + 1].strip()
    
    # 提取关键信息（例如 `0-两手托天理三焦（八段锦）_reference_0`）
    if "(标签:" in label_line:
        end_idx = label_line.find(" (标签:")
        key_info = label_line[:end_idx]  # 提取文件名关键部分
    
        # 解析文件路径
        action_folder = key_info.split("_")[0]
        filename_pattern = key_info.split("_", 1)[1]  # 提取 `reference_0`
        
        folder_path = os.path.join(video_base_path, action_folder)
        # 查找匹配的文件
        matching_files = [f for f in os.listdir(folder_path) if filename_pattern in f]
        if matching_files:
            # 提取文件名中的标签值
            file_name = matching_files[0]  # 假设只有一个匹配文件
            label_start = file_name.rfind("_") + 1
            label_end = file_name.rfind(".mp4")
            label_value = float(file_name[label_start:label_end])  # 提取标签值
            
            # 提取 14 维向量数据
            data_values = list(map(float, data_line.split()))
            
            # 检查数据和标签范围
            if len(data_values) == 14 and all(0 <= v <= 1 for v in data_values) and 0 <= label_value <= 1:
                features.append(data_values)
                labels.append(label_value)
    
    i += 2  # 跳过标签行和数据行

# 转换为 NumPy 数组
features = np.array(features)
labels = np.array(labels)

# 检查数据范围
print("Feature values range:", np.min(features), np.max(features))
print("Label values range:", np.min(labels), np.max(labels))

# 构建 TensorFlow 数据集
dataset = tf.data.Dataset.from_tensor_slices((features, labels))
train_size = int(0.7 * len(dataset))
train_dataset = dataset.take(train_size).batch(128)
val_dataset = dataset.skip(train_size).batch(128)


print(f"数据集构建完成：总样本数 {len(labels)}")
print(f"训练集样本数 {train_size}, 验证集样本数 {len(labels) - train_size}")
# Out:
# Feature values range: 7.3049926e-15 0.9993037
# Label values range: 0.35125 1.0
# 数据集构建完成：总样本数 699
# 训练集样本数 489, 验证集样本数 210

# %%
import tensorflow as tf
def save_dataset(dataset, save_path):
    """
    使用最新方法保存 TensorFlow 数据集。
    
    Args:
        dataset: tf.data.Dataset 对象。
        save_path: 保存路径。
    """
    dataset.save(save_path)
    print(f"数据集已保存到: {save_path}")

# 保存数据集
save_path = "C:/data/result/saved_dataset_score_true"
save_dataset(dataset, save_path)
# Out:
# 数据集已保存到: C:/data/result/saved_dataset_score_true

# %%
import tensorflow as tf
def load_dataset(save_path):
    """
    加载保存的 tf.data.Dataset 对象。
    
    Args:
        save_path: 保存的路径。
    
    Returns:
        加载的 tf.data.Dataset 对象。
    """
    dataset = tf.data.Dataset.load(save_path)
    print(f"数据集已从: {save_path} 加载")
    return dataset
save_path = "C:/data/result/saved_dataset_score_true"
# 加载数据集
dataset = load_dataset(save_path)

# 检查加载后的数据集
for features, labels in loaded_dataset.take(1):
    print("Features:", features.numpy())
    print("Labels:", labels.numpy())
# Out:
# 数据集已从: C:/data/result/saved_dataset_score_true 加载
# Features: [9.95986900e-01 8.18129050e-06 8.77484100e-06 5.78878000e-08
#  4.54797500e-06 3.13687130e-06 4.72669000e-09 9.77272400e-04
#  1.68164000e-03 1.30030960e-09 1.32916580e-03 6.90987600e-09
#  3.64507400e-07 1.03542185e-07]
# Labels: 0.871667

# %%
import os

OUTPUT_DIR = "C:/data/result/scene_detector"  # 替换为实际路径

# 获取文件夹中的文件和文件夹列表
folder_list = os.listdir(OUTPUT_DIR)

# 输出原始顺序
print("原始读取顺序：")
for i, folder_name in enumerate(folder_list):
    print(f"{i + 1}: {folder_name}")
# Out:
# 原始读取顺序：
# 1: 0-两手托天理三焦（八段锦）
# 2: 1-左右开弓似射雕（八段锦）
# 3: 10鹿抵（五禽戏）
# 4: 11鹿奔（五禽戏）
# 5: 12鸟伸（五禽戏）
# 6: 13鸟飞（五禽戏）
# 7: 14其他
# 8: 2-调理脾胃单臂举（八段锦）
# 9: 3-五劳七伤往后瞧（八段锦）
# 10: 4-摇头摆尾去心火（八段锦）
# 11: 5-两手攀足固肾腰（八段锦）
# 12: 6-攒拳怒目增气力（八段锦）
# 13: 7背后七颠百病消（八段锦）
# 14: 8虎举（五禽戏）
# 15: 9虎扑（五禽戏）

# %%
# 检查数据集
for data, label in dataset.take(1):
    print("数据向量 (1×14):", data.numpy())
    print("标签值:", label.numpy())
# Out:
# 数据向量 (1×14): [9.95986900e-01 8.18129050e-06 8.77484100e-06 5.78878000e-08
#  4.54797500e-06 3.13687130e-06 4.72669000e-09 9.77272400e-04
#  1.68164000e-03 1.30030960e-09 1.32916580e-03 6.90987600e-09
#  3.64507400e-07 1.03542185e-07]
# 标签值: 0.871667

# %%
import numpy as np
# 提取训练集和验证集中的特征和标签
train_features, train_labels = [], []
val_features, val_labels = [], []

# 遍历训练集
for features, labels in train_dataset:
    train_features.append(features.numpy())  # 转换为 NumPy 数组
    train_labels.append(labels.numpy())

# 遍历验证集
for features, labels in val_dataset:
    val_features.append(features.numpy())
    val_labels.append(labels.numpy())

# 拼接所有批次
train_features = np.concatenate(train_features, axis=0)
train_labels = np.concatenate(train_labels, axis=0)
val_features = np.concatenate(val_features, axis=0)
val_labels = np.concatenate(val_labels, axis=0)

# 统计每个 14 维向量的最大值
train_feature_max = np.max(train_features, axis=1)  # 训练集每个向量的最大值
val_feature_max = np.max(val_features, axis=1)      # 验证集每个向量的最大值

# 找到这些最大值的最大值和最小值
overall_max_max = max(np.max(train_feature_max), np.max(val_feature_max))  # 所有最大值的最大值
overall_min_max = min(np.min(train_feature_max), np.min(val_feature_max))  # 所有最大值的最小值

# 打印结果
print("Training features range:", np.min(train_features), np.max(train_features))
print("Training labels range:", np.min(train_labels), np.max(train_labels))
print("Validation features range:", np.min(val_features), np.max(val_features))
print("Validation labels range:", np.min(val_labels), np.max(val_labels))
print("Maximum of max values across all features:", overall_max_max)
print("Minimum of max values across all features:", overall_min_max)
# Out:
# Training features range: 7.3049926e-15 0.9993037
# Training labels range: 0.35125 1.0
# Validation features range: 8.8999656e-14 0.9768819
# Validation labels range: 0.56 1.0
# Maximum of max values across all features: 0.9993037
# Minimum of max values across all features: 0.23587419

# %%
# 直接将 dataset 划分为训练集和测试集
train_size = int(0.9 * len(dataset))  # 80% 用于训练
train_dataset = dataset.take(train_size).batch(128)
val_dataset = dataset.skip(train_size).batch(128)

# %%
from tensorflow.keras import layers, Model

# 定义 Wide & Deep 模型
def build_wide_and_deep_model(input_dim):
    # 输入层
    inputs = layers.Input(shape=(input_dim,))

    # Wide 部分（线性模型）
    wide_output = layers.Dense(1, activation="linear", name="wide")(inputs)

    # Deep 部分，尝试去掉正则化
    deep = layers.Dense(128, activation="relu")(inputs)  # 增加神经元数量
    deep = layers.Dense(64, activation="relu")(deep)
    deep_output = layers.Dense(1, activation="linear", name="deep")(deep)

    # 合并 Wide 和 Deep 部分
    combined = layers.Add()([wide_output, deep_output])

    # 输出层，使用sigmoid激活函数，确保输出在[0, 1]范围内
    outputs = layers.Activation("sigmoid")(combined)

    # 构建模型
    model = Model(inputs=inputs, outputs=outputs, name="Wide_Deep_Model")
    return model

# 获取输入维度（14维）
input_dim = 14
model = build_wide_and_deep_model(input_dim)

# 查看模型结构
model.summary()
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),
              loss="mean_squared_error",
              metrics=["mean_squared_error"])
# Out:
# Model: "Wide_Deep_Model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_34 (InputLayer)          [(None, 14)]         0           []
#
#  dense_71 (Dense)               (None, 128)          1920        ['input_34[0][0]']
#
#  dense_72 (Dense)               (None, 64)           8256        ['dense_71[0][0]']
#
#  wide (Dense)                   (None, 1)            15          ['input_34[0][0]']
#
#  deep (Dense)                   (None, 1)            65          ['dense_72[0][0]']
#
#  add_36 (Add)                   (None, 1)            0           ['wide[0][0]',
#                                                                   'deep[0][0]']
#
#  activation_32 (Activation)     (None, 1)            0           ['add_36[0][0]']
#
# ==================================================================================================
# Total params: 10,256
# Trainable params: 10,256
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 启动训练
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=1,  # 训练50轮
    verbose=1
)
# Out:
# 4/4 [==============================] - 1s 168ms/step - loss: 0.0666 - mean_squared_error: 0.0666 - val_loss: 0.0482 - val_mean_squared_error: 0.0482

# %%
print("Training labels range:", np.min(y_train), np.max(y_train))
print("Validation labels range:", np.min(y_val), np.max(y_val))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 print("Training labels range:", np.min(y_train), np.max(y_train))
#       2 print("Validation labels range:", np.min(y_val), np.max(y_val))
#
# NameError: name 'y_train' is not defined

# %%
import tensorflow as tf

# 定义路径
best_model_path = "c:/data/result/model/score/best_model.h5"

# 早停回调：连续20轮验证MSE未改善停止训练
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_mean_squared_error',  # 监控验证集MSE
    patience=50,                      # 容忍连续20轮无改善
    mode='min',                       # 最小化MSE
    verbose=1
)

# 模型检查点回调：保存验证MSE最小的模型
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=best_model_path,         # 保存路径
    monitor='val_mean_squared_error', # 监控验证集MSE
    save_best_only=True,              # 仅保存验证MSE最小的模型
    mode='min',                       # 最小化MSE
    verbose=1
)

# 启动训练
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=500,  # 最大训练轮次
    callbacks=[early_stopping, model_checkpoint],  # 加入回调
    verbose=1
)
# Out:
# Epoch 1/500
# 5/5 [==============================] - ETA: 0s - loss: 1859.0302 - mean_squared_error: 1859.0302
# Epoch 1: val_mean_squared_error improved from inf to 0.66471, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 1s 86ms/step - loss: 1859.0302 - mean_squared_error: 1859.0302 - val_loss: 0.6647 - val_mean_squared_error: 0.6647
# Epoch 2/500
# 5/5 [==============================] - ETA: 0s - loss: 1858.8745 - mean_squared_error: 1858.8745
# Epoch 2: val_mean_squared_error improved from 0.66471 to 0.65499, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 124ms/step - loss: 1858.8745 - mean_squared_error: 1858.8745 - val_loss: 0.6550 - val_mean_squared_error: 0.6550
# Epoch 3/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8932 - mean_squared_error: 0.8932
# Epoch 3: val_mean_squared_error improved from 0.65499 to 0.64542, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 20ms/step - loss: 1858.7267 - mean_squared_error: 1858.7267 - val_loss: 0.6454 - val_mean_squared_error: 0.6454
# Epoch 4/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8773 - mean_squared_error: 0.8773
# Epoch 4: val_mean_squared_error improved from 0.64542 to 0.63599, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1858.5781 - mean_squared_error: 1858.5781 - val_loss: 0.6360 - val_mean_squared_error: 0.6360
# Epoch 5/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8616 - mean_squared_error: 0.8616
# Epoch 5: val_mean_squared_error improved from 0.63599 to 0.62676, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1858.4301 - mean_squared_error: 1858.4301 - val_loss: 0.6268 - val_mean_squared_error: 0.6268
# Epoch 6/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8467 - mean_squared_error: 0.8467
# Epoch 6: val_mean_squared_error improved from 0.62676 to 0.61771, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1858.2825 - mean_squared_error: 1858.2825 - val_loss: 0.6177 - val_mean_squared_error: 0.6177
# Epoch 7/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8319 - mean_squared_error: 0.8319
# Epoch 7: val_mean_squared_error improved from 0.61771 to 0.60884, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1858.1357 - mean_squared_error: 1858.1357 - val_loss: 0.6088 - val_mean_squared_error: 0.6088
# Epoch 8/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8173 - mean_squared_error: 0.8173
# Epoch 8: val_mean_squared_error improved from 0.60884 to 0.60007, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1857.9919 - mean_squared_error: 1857.9919 - val_loss: 0.6001 - val_mean_squared_error: 0.6001
# Epoch 9/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8029 - mean_squared_error: 0.8029
# Epoch 9: val_mean_squared_error improved from 0.60007 to 0.59152, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 19ms/step - loss: 1857.8511 - mean_squared_error: 1857.8511 - val_loss: 0.5915 - val_mean_squared_error: 0.5915
# Epoch 10/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7888 - mean_squared_error: 0.7888
# Epoch 10: val_mean_squared_error improved from 0.59152 to 0.58312, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1857.7103 - mean_squared_error: 1857.7103 - val_loss: 0.5831 - val_mean_squared_error: 0.5831
# Epoch 11/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7749 - mean_squared_error: 0.7749
# Epoch 11: val_mean_squared_error improved from 0.58312 to 0.57480, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1857.5677 - mean_squared_error: 1857.5677 - val_loss: 0.5748 - val_mean_squared_error: 0.5748
# Epoch 12/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7613 - mean_squared_error: 0.7613
# Epoch 12: val_mean_squared_error improved from 0.57480 to 0.56664, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 19ms/step - loss: 1857.4266 - mean_squared_error: 1857.4266 - val_loss: 0.5666 - val_mean_squared_error: 0.5666
# Epoch 13/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7484 - mean_squared_error: 0.7484
# Epoch 13: val_mean_squared_error improved from 0.56664 to 0.55867, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 22ms/step - loss: 1857.2866 - mean_squared_error: 1857.2866 - val_loss: 0.5587 - val_mean_squared_error: 0.5587
# Epoch 14/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7359 - mean_squared_error: 0.7359
# Epoch 14: val_mean_squared_error improved from 0.55867 to 0.55081, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 19ms/step - loss: 1857.1467 - mean_squared_error: 1857.1467 - val_loss: 0.5508 - val_mean_squared_error: 0.5508
# Epoch 15/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7234 - mean_squared_error: 0.7234
# Epoch 15: val_mean_squared_error improved from 0.55081 to 0.54299, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1857.0073 - mean_squared_error: 1857.0073 - val_loss: 0.5430 - val_mean_squared_error: 0.5430
# Epoch 16/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7106 - mean_squared_error: 0.7106
# Epoch 16: val_mean_squared_error improved from 0.54299 to 0.53512, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1856.8685 - mean_squared_error: 1856.8685 - val_loss: 0.5351 - val_mean_squared_error: 0.5351
# Epoch 17/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6974 - mean_squared_error: 0.6974
# Epoch 17: val_mean_squared_error improved from 0.53512 to 0.52722, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1856.7294 - mean_squared_error: 1856.7294 - val_loss: 0.5272 - val_mean_squared_error: 0.5272
# Epoch 18/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6843 - mean_squared_error: 0.6843
# Epoch 18: val_mean_squared_error improved from 0.52722 to 0.51924, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1856.5897 - mean_squared_error: 1856.5897 - val_loss: 0.5192 - val_mean_squared_error: 0.5192
# Epoch 19/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6710 - mean_squared_error: 0.6710
# Epoch 19: val_mean_squared_error improved from 0.51924 to 0.51123, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1856.4390 - mean_squared_error: 1856.4390 - val_loss: 0.5112 - val_mean_squared_error: 0.5112
# Epoch 20/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6576 - mean_squared_error: 0.6576
# Epoch 20: val_mean_squared_error improved from 0.51123 to 0.50331, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1856.2896 - mean_squared_error: 1856.2896 - val_loss: 0.5033 - val_mean_squared_error: 0.5033
# Epoch 21/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6444 - mean_squared_error: 0.6444
# Epoch 21: val_mean_squared_error improved from 0.50331 to 0.49544, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1856.1384 - mean_squared_error: 1856.1384 - val_loss: 0.4954 - val_mean_squared_error: 0.4954
# Epoch 22/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6312 - mean_squared_error: 0.6312
# Epoch 22: val_mean_squared_error improved from 0.49544 to 0.48764, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1855.9877 - mean_squared_error: 1855.9877 - val_loss: 0.4876 - val_mean_squared_error: 0.4876
# Epoch 23/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6181 - mean_squared_error: 0.6181
# Epoch 23: val_mean_squared_error improved from 0.48764 to 0.47993, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1855.8340 - mean_squared_error: 1855.8340 - val_loss: 0.4799 - val_mean_squared_error: 0.4799
# Epoch 24/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6051 - mean_squared_error: 0.6051
# Epoch 24: val_mean_squared_error improved from 0.47993 to 0.47225, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1855.6743 - mean_squared_error: 1855.6743 - val_loss: 0.4722 - val_mean_squared_error: 0.4722
# Epoch 25/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5921 - mean_squared_error: 0.5921
# Epoch 25: val_mean_squared_error improved from 0.47225 to 0.46467, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1855.5154 - mean_squared_error: 1855.5154 - val_loss: 0.4647 - val_mean_squared_error: 0.4647
# Epoch 26/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5794 - mean_squared_error: 0.5794
# Epoch 26: val_mean_squared_error improved from 0.46467 to 0.45722, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1855.3562 - mean_squared_error: 1855.3562 - val_loss: 0.4572 - val_mean_squared_error: 0.4572
# Epoch 27/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5667 - mean_squared_error: 0.5667
# Epoch 27: val_mean_squared_error improved from 0.45722 to 0.44989, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 19ms/step - loss: 1855.2090 - mean_squared_error: 1855.2090 - val_loss: 0.4499 - val_mean_squared_error: 0.4499
# Epoch 28/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5544 - mean_squared_error: 0.5544
# Epoch 28: val_mean_squared_error improved from 0.44989 to 0.44261, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1855.0677 - mean_squared_error: 1855.0677 - val_loss: 0.4426 - val_mean_squared_error: 0.4426
# Epoch 29/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5423 - mean_squared_error: 0.5423
# Epoch 29: val_mean_squared_error improved from 0.44261 to 0.43539, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1854.9291 - mean_squared_error: 1854.9291 - val_loss: 0.4354 - val_mean_squared_error: 0.4354
# Epoch 30/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5307 - mean_squared_error: 0.5307
# Epoch 30: val_mean_squared_error improved from 0.43539 to 0.42820, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1854.7882 - mean_squared_error: 1854.7882 - val_loss: 0.4282 - val_mean_squared_error: 0.4282
# Epoch 31/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5190 - mean_squared_error: 0.5190
# Epoch 31: val_mean_squared_error improved from 0.42820 to 0.42099, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1854.6494 - mean_squared_error: 1854.6494 - val_loss: 0.4210 - val_mean_squared_error: 0.4210
# Epoch 32/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5077 - mean_squared_error: 0.5077
# Epoch 32: val_mean_squared_error improved from 0.42099 to 0.41386, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1854.5116 - mean_squared_error: 1854.5116 - val_loss: 0.4139 - val_mean_squared_error: 0.4139
# Epoch 33/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4966 - mean_squared_error: 0.4966
# Epoch 33: val_mean_squared_error improved from 0.41386 to 0.40677, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1854.3761 - mean_squared_error: 1854.3761 - val_loss: 0.4068 - val_mean_squared_error: 0.4068
# Epoch 34/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4857 - mean_squared_error: 0.4857
# Epoch 34: val_mean_squared_error improved from 0.40677 to 0.39978, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1854.2395 - mean_squared_error: 1854.2395 - val_loss: 0.3998 - val_mean_squared_error: 0.3998
# Epoch 35/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4748 - mean_squared_error: 0.4748
# Epoch 35: val_mean_squared_error improved from 0.39978 to 0.39278, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1854.1034 - mean_squared_error: 1854.1034 - val_loss: 0.3928 - val_mean_squared_error: 0.3928
# Epoch 36/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4640 - mean_squared_error: 0.4640
# Epoch 36: val_mean_squared_error improved from 0.39278 to 0.38574, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1853.9663 - mean_squared_error: 1853.9663 - val_loss: 0.3857 - val_mean_squared_error: 0.3857
# Epoch 37/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4531 - mean_squared_error: 0.4531
# Epoch 37: val_mean_squared_error improved from 0.38574 to 0.37874, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1853.8282 - mean_squared_error: 1853.8282 - val_loss: 0.3787 - val_mean_squared_error: 0.3787
# Epoch 38/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4423 - mean_squared_error: 0.4423
# Epoch 38: val_mean_squared_error improved from 0.37874 to 0.37178, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1853.6903 - mean_squared_error: 1853.6903 - val_loss: 0.3718 - val_mean_squared_error: 0.3718
# Epoch 39/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4317 - mean_squared_error: 0.4317
# Epoch 39: val_mean_squared_error improved from 0.37178 to 0.36490, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1853.5514 - mean_squared_error: 1853.5514 - val_loss: 0.3649 - val_mean_squared_error: 0.3649
# Epoch 40/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4212 - mean_squared_error: 0.4212
# Epoch 40: val_mean_squared_error improved from 0.36490 to 0.35804, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1853.4139 - mean_squared_error: 1853.4139 - val_loss: 0.3580 - val_mean_squared_error: 0.3580
# Epoch 41/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4108 - mean_squared_error: 0.4108
# Epoch 41: val_mean_squared_error improved from 0.35804 to 0.35120, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 19ms/step - loss: 1853.2754 - mean_squared_error: 1853.2754 - val_loss: 0.3512 - val_mean_squared_error: 0.3512
# Epoch 42/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4003 - mean_squared_error: 0.4003
# Epoch 42: val_mean_squared_error improved from 0.35120 to 0.34440, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1853.1372 - mean_squared_error: 1853.1372 - val_loss: 0.3444 - val_mean_squared_error: 0.3444
# Epoch 43/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3899 - mean_squared_error: 0.3899
# Epoch 43: val_mean_squared_error improved from 0.34440 to 0.33757, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1852.9969 - mean_squared_error: 1852.9969 - val_loss: 0.3376 - val_mean_squared_error: 0.3376
# Epoch 44/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3793 - mean_squared_error: 0.3793
# Epoch 44: val_mean_squared_error improved from 0.33757 to 0.33070, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 19ms/step - loss: 1852.8353 - mean_squared_error: 1852.8353 - val_loss: 0.3307 - val_mean_squared_error: 0.3307
# Epoch 45/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3686 - mean_squared_error: 0.3686
# Epoch 45: val_mean_squared_error improved from 0.33070 to 0.32383, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1852.6578 - mean_squared_error: 1852.6578 - val_loss: 0.3238 - val_mean_squared_error: 0.3238
# Epoch 46/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3578 - mean_squared_error: 0.3578
# Epoch 46: val_mean_squared_error improved from 0.32383 to 0.31696, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1852.4855 - mean_squared_error: 1852.4855 - val_loss: 0.3170 - val_mean_squared_error: 0.3170
# Epoch 47/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3470 - mean_squared_error: 0.3470
# Epoch 47: val_mean_squared_error improved from 0.31696 to 0.31016, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1852.3099 - mean_squared_error: 1852.3099 - val_loss: 0.3102 - val_mean_squared_error: 0.3102
# Epoch 48/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3362 - mean_squared_error: 0.3362
# Epoch 48: val_mean_squared_error improved from 0.31016 to 0.30353, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1852.1345 - mean_squared_error: 1852.1345 - val_loss: 0.3035 - val_mean_squared_error: 0.3035
# Epoch 49/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3257 - mean_squared_error: 0.3257
# Epoch 49: val_mean_squared_error improved from 0.30353 to 0.29698, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1851.9574 - mean_squared_error: 1851.9574 - val_loss: 0.2970 - val_mean_squared_error: 0.2970
# Epoch 50/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3154 - mean_squared_error: 0.3154
# Epoch 50: val_mean_squared_error improved from 0.29698 to 0.29056, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1851.7848 - mean_squared_error: 1851.7848 - val_loss: 0.2906 - val_mean_squared_error: 0.2906
# Epoch 51/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3053 - mean_squared_error: 0.3053
# Epoch 51: val_mean_squared_error improved from 0.29056 to 0.28422, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1851.6132 - mean_squared_error: 1851.6132 - val_loss: 0.2842 - val_mean_squared_error: 0.2842
# Epoch 52/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2954 - mean_squared_error: 0.2954
# Epoch 52: val_mean_squared_error improved from 0.28422 to 0.27798, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1851.4412 - mean_squared_error: 1851.4412 - val_loss: 0.2780 - val_mean_squared_error: 0.2780
# Epoch 53/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2857 - mean_squared_error: 0.2857
# Epoch 53: val_mean_squared_error improved from 0.27798 to 0.27185, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1851.2721 - mean_squared_error: 1851.2721 - val_loss: 0.2719 - val_mean_squared_error: 0.2719
# Epoch 54/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2762 - mean_squared_error: 0.2762
# Epoch 54: val_mean_squared_error improved from 0.27185 to 0.26583, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1851.1040 - mean_squared_error: 1851.1040 - val_loss: 0.2658 - val_mean_squared_error: 0.2658
# Epoch 55/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2669 - mean_squared_error: 0.2669
# Epoch 55: val_mean_squared_error improved from 0.26583 to 0.25991, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 21ms/step - loss: 1850.9364 - mean_squared_error: 1850.9364 - val_loss: 0.2599 - val_mean_squared_error: 0.2599
# Epoch 56/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2578 - mean_squared_error: 0.2578
# Epoch 56: val_mean_squared_error improved from 0.25991 to 0.25407, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1850.7753 - mean_squared_error: 1850.7753 - val_loss: 0.2541 - val_mean_squared_error: 0.2541
# Epoch 57/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2490 - mean_squared_error: 0.2490
# Epoch 57: val_mean_squared_error improved from 0.25407 to 0.24832, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1850.6173 - mean_squared_error: 1850.6173 - val_loss: 0.2483 - val_mean_squared_error: 0.2483
# Epoch 58/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2404 - mean_squared_error: 0.2404
# Epoch 58: val_mean_squared_error improved from 0.24832 to 0.24264, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1850.4573 - mean_squared_error: 1850.4573 - val_loss: 0.2426 - val_mean_squared_error: 0.2426
# Epoch 59/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2319 - mean_squared_error: 0.2319
# Epoch 59: val_mean_squared_error improved from 0.24264 to 0.23691, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1850.2810 - mean_squared_error: 1850.2810 - val_loss: 0.2369 - val_mean_squared_error: 0.2369
# Epoch 60/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2234 - mean_squared_error: 0.2234
# Epoch 60: val_mean_squared_error improved from 0.23691 to 0.23120, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1850.0936 - mean_squared_error: 1850.0936 - val_loss: 0.2312 - val_mean_squared_error: 0.2312
# Epoch 61/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2148 - mean_squared_error: 0.2148
# Epoch 61: val_mean_squared_error improved from 0.23120 to 0.22554, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1849.9131 - mean_squared_error: 1849.9131 - val_loss: 0.2255 - val_mean_squared_error: 0.2255
# Epoch 62/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2062 - mean_squared_error: 0.2062
# Epoch 62: val_mean_squared_error improved from 0.22554 to 0.21994, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1849.7312 - mean_squared_error: 1849.7312 - val_loss: 0.2199 - val_mean_squared_error: 0.2199
# Epoch 63/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1977 - mean_squared_error: 0.1977
# Epoch 63: val_mean_squared_error improved from 0.21994 to 0.21449, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1849.5482 - mean_squared_error: 1849.5482 - val_loss: 0.2145 - val_mean_squared_error: 0.2145
# Epoch 64/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1893 - mean_squared_error: 0.1893
# Epoch 64: val_mean_squared_error improved from 0.21449 to 0.20917, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1849.3658 - mean_squared_error: 1849.3658 - val_loss: 0.2092 - val_mean_squared_error: 0.2092
# Epoch 65/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1812 - mean_squared_error: 0.1812
# Epoch 65: val_mean_squared_error improved from 0.20917 to 0.20400, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1849.1840 - mean_squared_error: 1849.1840 - val_loss: 0.2040 - val_mean_squared_error: 0.2040
# Epoch 66/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1733 - mean_squared_error: 0.1733
# Epoch 66: val_mean_squared_error improved from 0.20400 to 0.19897, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1849.0015 - mean_squared_error: 1849.0015 - val_loss: 0.1990 - val_mean_squared_error: 0.1990
# Epoch 67/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1656 - mean_squared_error: 0.1656
# Epoch 67: val_mean_squared_error improved from 0.19897 to 0.19405, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1848.8192 - mean_squared_error: 1848.8192 - val_loss: 0.1940 - val_mean_squared_error: 0.1940
# Epoch 68/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1582 - mean_squared_error: 0.1582
# Epoch 68: val_mean_squared_error improved from 0.19405 to 0.18923, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1848.6355 - mean_squared_error: 1848.6355 - val_loss: 0.1892 - val_mean_squared_error: 0.1892
# Epoch 69/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1510 - mean_squared_error: 0.1510
# Epoch 69: val_mean_squared_error improved from 0.18923 to 0.18456, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1848.4535 - mean_squared_error: 1848.4535 - val_loss: 0.1846 - val_mean_squared_error: 0.1846
# Epoch 70/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1440 - mean_squared_error: 0.1440
# Epoch 70: val_mean_squared_error improved from 0.18456 to 0.18005, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1848.2733 - mean_squared_error: 1848.2733 - val_loss: 0.1801 - val_mean_squared_error: 0.1801
# Epoch 71/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1373 - mean_squared_error: 0.1373
# Epoch 71: val_mean_squared_error improved from 0.18005 to 0.17563, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1848.0900 - mean_squared_error: 1848.0900 - val_loss: 0.1756 - val_mean_squared_error: 0.1756
# Epoch 72/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1307 - mean_squared_error: 0.1307
# Epoch 72: val_mean_squared_error improved from 0.17563 to 0.17136, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1847.9082 - mean_squared_error: 1847.9082 - val_loss: 0.1714 - val_mean_squared_error: 0.1714
# Epoch 73/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1245 - mean_squared_error: 0.1245
# Epoch 73: val_mean_squared_error improved from 0.17136 to 0.16720, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1847.7263 - mean_squared_error: 1847.7263 - val_loss: 0.1672 - val_mean_squared_error: 0.1672
# Epoch 74/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1184 - mean_squared_error: 0.1184
# Epoch 74: val_mean_squared_error improved from 0.16720 to 0.16319, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1847.5449 - mean_squared_error: 1847.5449 - val_loss: 0.1632 - val_mean_squared_error: 0.1632
# Epoch 75/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1126 - mean_squared_error: 0.1126
# Epoch 75: val_mean_squared_error improved from 0.16319 to 0.15922, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1847.3618 - mean_squared_error: 1847.3618 - val_loss: 0.1592 - val_mean_squared_error: 0.1592
# Epoch 76/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1069 - mean_squared_error: 0.1069
# Epoch 76: val_mean_squared_error improved from 0.15922 to 0.15545, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1847.1826 - mean_squared_error: 1847.1826 - val_loss: 0.1555 - val_mean_squared_error: 0.1555
# Epoch 77/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1015 - mean_squared_error: 0.1015
# Epoch 77: val_mean_squared_error improved from 0.15545 to 0.15179, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1846.9989 - mean_squared_error: 1846.9989 - val_loss: 0.1518 - val_mean_squared_error: 0.1518
# Epoch 78/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0963 - mean_squared_error: 0.0963
# Epoch 78: val_mean_squared_error improved from 0.15179 to 0.14824, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1846.8171 - mean_squared_error: 1846.8171 - val_loss: 0.1482 - val_mean_squared_error: 0.1482
# Epoch 79/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0913 - mean_squared_error: 0.0913
# Epoch 79: val_mean_squared_error improved from 0.14824 to 0.14474, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1846.6359 - mean_squared_error: 1846.6359 - val_loss: 0.1447 - val_mean_squared_error: 0.1447
# Epoch 80/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0866 - mean_squared_error: 0.0866
# Epoch 80: val_mean_squared_error improved from 0.14474 to 0.14134, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1846.4521 - mean_squared_error: 1846.4521 - val_loss: 0.1413 - val_mean_squared_error: 0.1413
# Epoch 81/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0820 - mean_squared_error: 0.0820
# Epoch 81: val_mean_squared_error improved from 0.14134 to 0.13804, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 15ms/step - loss: 1846.2682 - mean_squared_error: 1846.2682 - val_loss: 0.1380 - val_mean_squared_error: 0.1380
# Epoch 82/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0776 - mean_squared_error: 0.0776
# Epoch 82: val_mean_squared_error improved from 0.13804 to 0.13488, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1846.0884 - mean_squared_error: 1846.0884 - val_loss: 0.1349 - val_mean_squared_error: 0.1349
# Epoch 83/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0735 - mean_squared_error: 0.0735
# Epoch 83: val_mean_squared_error improved from 0.13488 to 0.13181, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1845.9056 - mean_squared_error: 1845.9056 - val_loss: 0.1318 - val_mean_squared_error: 0.1318
# Epoch 84/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0695 - mean_squared_error: 0.0695
# Epoch 84: val_mean_squared_error improved from 0.13181 to 0.12888, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1845.7231 - mean_squared_error: 1845.7231 - val_loss: 0.1289 - val_mean_squared_error: 0.1289
# Epoch 85/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0657 - mean_squared_error: 0.0657
# Epoch 85: val_mean_squared_error improved from 0.12888 to 0.12605, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1845.5414 - mean_squared_error: 1845.5414 - val_loss: 0.1261 - val_mean_squared_error: 0.1261
# Epoch 86/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0620 - mean_squared_error: 0.0620
# Epoch 86: val_mean_squared_error improved from 0.12605 to 0.12330, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1845.3553 - mean_squared_error: 1845.3553 - val_loss: 0.1233 - val_mean_squared_error: 0.1233
# Epoch 87/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0585 - mean_squared_error: 0.0585
# Epoch 87: val_mean_squared_error improved from 0.12330 to 0.12068, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 19ms/step - loss: 1845.1708 - mean_squared_error: 1845.1708 - val_loss: 0.1207 - val_mean_squared_error: 0.1207
# Epoch 88/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0551 - mean_squared_error: 0.0551
# Epoch 88: val_mean_squared_error improved from 0.12068 to 0.11819, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1844.9869 - mean_squared_error: 1844.9869 - val_loss: 0.1182 - val_mean_squared_error: 0.1182
# Epoch 89/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0520 - mean_squared_error: 0.0520
# Epoch 89: val_mean_squared_error improved from 0.11819 to 0.11577, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1844.8015 - mean_squared_error: 1844.8015 - val_loss: 0.1158 - val_mean_squared_error: 0.1158
# Epoch 90/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0489 - mean_squared_error: 0.0489
# Epoch 90: val_mean_squared_error improved from 0.11577 to 0.11346, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1844.6152 - mean_squared_error: 1844.6152 - val_loss: 0.1135 - val_mean_squared_error: 0.1135
# Epoch 91/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0460 - mean_squared_error: 0.0460
# Epoch 91: val_mean_squared_error improved from 0.11346 to 0.11124, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1844.4296 - mean_squared_error: 1844.4296 - val_loss: 0.1112 - val_mean_squared_error: 0.1112
# Epoch 92/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0433 - mean_squared_error: 0.0433
# Epoch 92: val_mean_squared_error improved from 0.11124 to 0.10914, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1844.2422 - mean_squared_error: 1844.2422 - val_loss: 0.1091 - val_mean_squared_error: 0.1091
# Epoch 93/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0408 - mean_squared_error: 0.0408
# Epoch 93: val_mean_squared_error improved from 0.10914 to 0.10711, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1844.0549 - mean_squared_error: 1844.0549 - val_loss: 0.1071 - val_mean_squared_error: 0.1071
# Epoch 94/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0384 - mean_squared_error: 0.0384
# Epoch 94: val_mean_squared_error improved from 0.10711 to 0.10522, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1843.8660 - mean_squared_error: 1843.8660 - val_loss: 0.1052 - val_mean_squared_error: 0.1052
# Epoch 95/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0361 - mean_squared_error: 0.0361
# Epoch 95: val_mean_squared_error improved from 0.10522 to 0.10339, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1843.6766 - mean_squared_error: 1843.6766 - val_loss: 0.1034 - val_mean_squared_error: 0.1034
# Epoch 96/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0340 - mean_squared_error: 0.0340
# Epoch 96: val_mean_squared_error improved from 0.10339 to 0.10169, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1843.4882 - mean_squared_error: 1843.4882 - val_loss: 0.1017 - val_mean_squared_error: 0.1017
# Epoch 97/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0320 - mean_squared_error: 0.0320
# Epoch 97: val_mean_squared_error improved from 0.10169 to 0.10005, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1843.2985 - mean_squared_error: 1843.2985 - val_loss: 0.1001 - val_mean_squared_error: 0.1001
# Epoch 98/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0301 - mean_squared_error: 0.0301
# Epoch 98: val_mean_squared_error improved from 0.10005 to 0.09854, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 1843.1050 - mean_squared_error: 1843.1050 - val_loss: 0.0985 - val_mean_squared_error: 0.0985
# Epoch 99/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0284 - mean_squared_error: 0.0284
# Epoch 99: val_mean_squared_error improved from 0.09854 to 0.09708, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1842.9148 - mean_squared_error: 1842.9148 - val_loss: 0.0971 - val_mean_squared_error: 0.0971
# Epoch 100/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0268 - mean_squared_error: 0.0268
# Epoch 100: val_mean_squared_error improved from 0.09708 to 0.09575, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1842.7234 - mean_squared_error: 1842.7234 - val_loss: 0.0957 - val_mean_squared_error: 0.0957
# Epoch 101/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0253 - mean_squared_error: 0.0253
# Epoch 101: val_mean_squared_error improved from 0.09575 to 0.09449, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 15ms/step - loss: 1842.5283 - mean_squared_error: 1842.5283 - val_loss: 0.0945 - val_mean_squared_error: 0.0945
# Epoch 102/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0239 - mean_squared_error: 0.0239
# Epoch 102: val_mean_squared_error improved from 0.09449 to 0.09330, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1842.3335 - mean_squared_error: 1842.3335 - val_loss: 0.0933 - val_mean_squared_error: 0.0933
# Epoch 103/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0226 - mean_squared_error: 0.0226
# Epoch 103: val_mean_squared_error improved from 0.09330 to 0.09221, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1842.1401 - mean_squared_error: 1842.1401 - val_loss: 0.0922 - val_mean_squared_error: 0.0922
# Epoch 104/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0215 - mean_squared_error: 0.0215
# Epoch 104: val_mean_squared_error improved from 0.09221 to 0.09120, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1841.9451 - mean_squared_error: 1841.9451 - val_loss: 0.0912 - val_mean_squared_error: 0.0912
# Epoch 105/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0204 - mean_squared_error: 0.0204
# Epoch 105: val_mean_squared_error improved from 0.09120 to 0.09027, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1841.7477 - mean_squared_error: 1841.7477 - val_loss: 0.0903 - val_mean_squared_error: 0.0903
# Epoch 106/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0195 - mean_squared_error: 0.0195
# Epoch 106: val_mean_squared_error improved from 0.09027 to 0.08943, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 15ms/step - loss: 1841.5504 - mean_squared_error: 1841.5504 - val_loss: 0.0894 - val_mean_squared_error: 0.0894
# Epoch 107/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0186 - mean_squared_error: 0.0186
# Epoch 107: val_mean_squared_error improved from 0.08943 to 0.08866, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1841.3547 - mean_squared_error: 1841.3547 - val_loss: 0.0887 - val_mean_squared_error: 0.0887
# Epoch 108/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0178 - mean_squared_error: 0.0178
# Epoch 108: val_mean_squared_error improved from 0.08866 to 0.08798, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1841.1545 - mean_squared_error: 1841.1545 - val_loss: 0.0880 - val_mean_squared_error: 0.0880
# Epoch 109/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0172 - mean_squared_error: 0.0172
# Epoch 109: val_mean_squared_error improved from 0.08798 to 0.08740, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 1840.9565 - mean_squared_error: 1840.9565 - val_loss: 0.0874 - val_mean_squared_error: 0.0874
# Epoch 110/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0166 - mean_squared_error: 0.0166
# Epoch 110: val_mean_squared_error improved from 0.08740 to 0.08686, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1840.7548 - mean_squared_error: 1840.7548 - val_loss: 0.0869 - val_mean_squared_error: 0.0869
# Epoch 111/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0161 - mean_squared_error: 0.0161
# Epoch 111: val_mean_squared_error improved from 0.08686 to 0.08642, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1840.5541 - mean_squared_error: 1840.5541 - val_loss: 0.0864 - val_mean_squared_error: 0.0864
# Epoch 112/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0156 - mean_squared_error: 0.0156
# Epoch 112: val_mean_squared_error improved from 0.08642 to 0.08607, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 1840.3527 - mean_squared_error: 1840.3527 - val_loss: 0.0861 - val_mean_squared_error: 0.0861
# Epoch 113/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0153 - mean_squared_error: 0.0153
# Epoch 113: val_mean_squared_error improved from 0.08607 to 0.08576, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1840.1488 - mean_squared_error: 1840.1488 - val_loss: 0.0858 - val_mean_squared_error: 0.0858
# Epoch 114/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0150 - mean_squared_error: 0.0150
# Epoch 114: val_mean_squared_error improved from 0.08576 to 0.08552, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 15ms/step - loss: 1839.9446 - mean_squared_error: 1839.9446 - val_loss: 0.0855 - val_mean_squared_error: 0.0855
# Epoch 115/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0148 - mean_squared_error: 0.0148
# Epoch 115: val_mean_squared_error improved from 0.08552 to 0.08537, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1839.7408 - mean_squared_error: 1839.7408 - val_loss: 0.0854 - val_mean_squared_error: 0.0854
# Epoch 116/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0146 - mean_squared_error: 0.0146
# Epoch 116: val_mean_squared_error improved from 0.08537 to 0.08527, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1839.5349 - mean_squared_error: 1839.5349 - val_loss: 0.0853 - val_mean_squared_error: 0.0853
# Epoch 117/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0145 - mean_squared_error: 0.0145
# Epoch 117: val_mean_squared_error improved from 0.08527 to 0.08522, saving model to c:/data/result/model/score\best_model.h5
# 5/5 [==============================] - 0s 16ms/step - loss: 1839.3278 - mean_squared_error: 1839.3278 - val_loss: 0.0852 - val_mean_squared_error: 0.0852
# Epoch 118/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0144 - mean_squared_error: 0.0144
# Epoch 118: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 12ms/step - loss: 1839.1196 - mean_squared_error: 1839.1196 - val_loss: 0.0852 - val_mean_squared_error: 0.0852
# Epoch 119/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0143 - mean_squared_error: 0.0143
# Epoch 119: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 12ms/step - loss: 1838.9088 - mean_squared_error: 1838.9088 - val_loss: 0.0853 - val_mean_squared_error: 0.0853
# Epoch 120/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0144 - mean_squared_error: 0.0144
# Epoch 120: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 13ms/step - loss: 1838.7012 - mean_squared_error: 1838.7012 - val_loss: 0.0854 - val_mean_squared_error: 0.0854
# Epoch 121/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0144 - mean_squared_error: 0.0144
# Epoch 121: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 12ms/step - loss: 1838.4886 - mean_squared_error: 1838.4886 - val_loss: 0.0856 - val_mean_squared_error: 0.0856
# Epoch 122/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0145 - mean_squared_error: 0.0145
# Epoch 122: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 13ms/step - loss: 1838.2770 - mean_squared_error: 1838.2770 - val_loss: 0.0857 - val_mean_squared_error: 0.0857
# Epoch 123/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0146 - mean_squared_error: 0.0146
# Epoch 123: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 12ms/step - loss: 1838.0662 - mean_squared_error: 1838.0662 - val_loss: 0.0860 - val_mean_squared_error: 0.0860
# Epoch 124/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0148 - mean_squared_error: 0.0148
# Epoch 124: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 11ms/step - loss: 1837.8508 - mean_squared_error: 1837.8508 - val_loss: 0.0863 - val_mean_squared_error: 0.0863
# Epoch 125/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0150 - mean_squared_error: 0.0150
# Epoch 125: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 10ms/step - loss: 1837.6355 - mean_squared_error: 1837.6355 - val_loss: 0.0866 - val_mean_squared_error: 0.0866
# Epoch 126/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0152 - mean_squared_error: 0.0152
# Epoch 126: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 11ms/step - loss: 1837.4208 - mean_squared_error: 1837.4208 - val_loss: 0.0870 - val_mean_squared_error: 0.0870
# Epoch 127/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0154 - mean_squared_error: 0.0154
# Epoch 127: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 12ms/step - loss: 1837.2034 - mean_squared_error: 1837.2034 - val_loss: 0.0874 - val_mean_squared_error: 0.0874
# Epoch 128/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0156 - mean_squared_error: 0.0156
# Epoch 128: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 11ms/step - loss: 1836.9806 - mean_squared_error: 1836.9806 - val_loss: 0.0879 - val_mean_squared_error: 0.0879
# Epoch 129/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0159 - mean_squared_error: 0.0159
# Epoch 129: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 11ms/step - loss: 1836.7581 - mean_squared_error: 1836.7581 - val_loss: 0.0883 - val_mean_squared_error: 0.0883
# Epoch 130/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0162 - mean_squared_error: 0.0162
# Epoch 130: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 10ms/step - loss: 1836.5358 - mean_squared_error: 1836.5358 - val_loss: 0.0888 - val_mean_squared_error: 0.0888
# Epoch 131/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0165 - mean_squared_error: 0.0165
# Epoch 131: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 12ms/step - loss: 1836.3079 - mean_squared_error: 1836.3079 - val_loss: 0.0894 - val_mean_squared_error: 0.0894
# Epoch 132/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0169 - mean_squared_error: 0.0169
# Epoch 132: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 10ms/step - loss: 1836.0787 - mean_squared_error: 1836.0787 - val_loss: 0.0899 - val_mean_squared_error: 0.0899
# Epoch 133/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0172 - mean_squared_error: 0.0172
# Epoch 133: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 9ms/step - loss: 1835.8510 - mean_squared_error: 1835.8510 - val_loss: 0.0905 - val_mean_squared_error: 0.0905
# Epoch 134/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0176 - mean_squared_error: 0.0176
# Epoch 134: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 11ms/step - loss: 1835.6174 - mean_squared_error: 1835.6174 - val_loss: 0.0911 - val_mean_squared_error: 0.0911
# Epoch 135/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0179 - mean_squared_error: 0.0179
# Epoch 135: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 11ms/step - loss: 1835.3848 - mean_squared_error: 1835.3848 - val_loss: 0.0918 - val_mean_squared_error: 0.0918
# Epoch 136/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0184 - mean_squared_error: 0.0184
# Epoch 136: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 12ms/step - loss: 1835.1521 - mean_squared_error: 1835.1521 - val_loss: 0.0925 - val_mean_squared_error: 0.0925
# Epoch 137/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0187 - mean_squared_error: 0.0187
# Epoch 137: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 11ms/step - loss: 1834.9146 - mean_squared_error: 1834.9146 - val_loss: 0.0932 - val_mean_squared_error: 0.0932
# Epoch 138/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0191 - mean_squared_error: 0.0191
# Epoch 138: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 12ms/step - loss: 1834.6820 - mean_squared_error: 1834.6820 - val_loss: 0.0939 - val_mean_squared_error: 0.0939
# Epoch 139/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0195 - mean_squared_error: 0.0195
# Epoch 139: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 10ms/step - loss: 1834.4415 - mean_squared_error: 1834.4415 - val_loss: 0.0947 - val_mean_squared_error: 0.0947
# Epoch 140/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0199 - mean_squared_error: 0.0199
# Epoch 140: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 10ms/step - loss: 1834.2034 - mean_squared_error: 1834.2034 - val_loss: 0.0954 - val_mean_squared_error: 0.0954
# Epoch 141/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0203 - mean_squared_error: 0.0203
# Epoch 141: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 12ms/step - loss: 1833.9622 - mean_squared_error: 1833.9622 - val_loss: 0.0962 - val_mean_squared_error: 0.0962
# Epoch 142/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0207 - mean_squared_error: 0.0207
# Epoch 142: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 10ms/step - loss: 1833.7198 - mean_squared_error: 1833.7198 - val_loss: 0.0971 - val_mean_squared_error: 0.0971
# Epoch 143/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0211 - mean_squared_error: 0.0211
# Epoch 143: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 10ms/step - loss: 1833.4767 - mean_squared_error: 1833.4767 - val_loss: 0.0979 - val_mean_squared_error: 0.0979
# Epoch 144/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0215 - mean_squared_error: 0.0215
# Epoch 144: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 10ms/step - loss: 1833.2296 - mean_squared_error: 1833.2296 - val_loss: 0.0988 - val_mean_squared_error: 0.0988
# Epoch 145/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0219 - mean_squared_error: 0.0219
# Epoch 145: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 12ms/step - loss: 1832.9872 - mean_squared_error: 1832.9872 - val_loss: 0.0997 - val_mean_squared_error: 0.0997
# Epoch 146/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0223 - mean_squared_error: 0.0223
# Epoch 146: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 10ms/step - loss: 1832.7377 - mean_squared_error: 1832.7377 - val_loss: 0.1006 - val_mean_squared_error: 0.1006
# Epoch 147/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0227 - mean_squared_error: 0.0227
# Epoch 147: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 9ms/step - loss: 1832.4882 - mean_squared_error: 1832.4882 - val_loss: 0.1015 - val_mean_squared_error: 0.1015
# Epoch 148/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0230 - mean_squared_error: 0.0230
# Epoch 148: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 12ms/step - loss: 1832.2373 - mean_squared_error: 1832.2373 - val_loss: 0.1025 - val_mean_squared_error: 0.1025
# Epoch 149/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0234 - mean_squared_error: 0.0234
# Epoch 149: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 11ms/step - loss: 1831.9851 - mean_squared_error: 1831.9851 - val_loss: 0.1035 - val_mean_squared_error: 0.1035
# Epoch 150/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0238 - mean_squared_error: 0.0238
# Epoch 150: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 10ms/step - loss: 1831.7336 - mean_squared_error: 1831.7336 - val_loss: 0.1044 - val_mean_squared_error: 0.1044
# Epoch 151/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0241 - mean_squared_error: 0.0241
# Epoch 151: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 10ms/step - loss: 1831.4794 - mean_squared_error: 1831.4794 - val_loss: 0.1054 - val_mean_squared_error: 0.1054
# Epoch 152/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0245 - mean_squared_error: 0.0245
# Epoch 152: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 11ms/step - loss: 1831.2218 - mean_squared_error: 1831.2218 - val_loss: 0.1063 - val_mean_squared_error: 0.1063
# Epoch 153/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0248 - mean_squared_error: 0.0248
# Epoch 153: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 11ms/step - loss: 1830.9664 - mean_squared_error: 1830.9664 - val_loss: 0.1073 - val_mean_squared_error: 0.1073
# Epoch 154/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0251 - mean_squared_error: 0.0251
# Epoch 154: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 10ms/step - loss: 1830.7079 - mean_squared_error: 1830.7079 - val_loss: 0.1082 - val_mean_squared_error: 0.1082
# Epoch 155/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0254 - mean_squared_error: 0.0254
# Epoch 155: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 10ms/step - loss: 1830.4454 - mean_squared_error: 1830.4454 - val_loss: 0.1092 - val_mean_squared_error: 0.1092
# Epoch 156/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0256 - mean_squared_error: 0.0256
# Epoch 156: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 10ms/step - loss: 1830.1846 - mean_squared_error: 1830.1846 - val_loss: 0.1102 - val_mean_squared_error: 0.1102
# Epoch 157/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0258 - mean_squared_error: 0.0258
# Epoch 157: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 10ms/step - loss: 1829.9224 - mean_squared_error: 1829.9224 - val_loss: 0.1112 - val_mean_squared_error: 0.1112
# Epoch 158/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0260 - mean_squared_error: 0.0260
# Epoch 158: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 10ms/step - loss: 1829.6578 - mean_squared_error: 1829.6578 - val_loss: 0.1121 - val_mean_squared_error: 0.1121
# Epoch 159/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0262 - mean_squared_error: 0.0262
# Epoch 159: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 9ms/step - loss: 1829.3900 - mean_squared_error: 1829.3900 - val_loss: 0.1131 - val_mean_squared_error: 0.1131
# Epoch 160/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0263 - mean_squared_error: 0.0263
# Epoch 160: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 12ms/step - loss: 1829.1213 - mean_squared_error: 1829.1213 - val_loss: 0.1140 - val_mean_squared_error: 0.1140
# Epoch 161/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0265 - mean_squared_error: 0.0265
# Epoch 161: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 12ms/step - loss: 1828.8507 - mean_squared_error: 1828.8507 - val_loss: 0.1150 - val_mean_squared_error: 0.1150
# Epoch 162/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0266 - mean_squared_error: 0.0266
# Epoch 162: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 11ms/step - loss: 1828.5817 - mean_squared_error: 1828.5817 - val_loss: 0.1161 - val_mean_squared_error: 0.1161
# Epoch 163/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0268 - mean_squared_error: 0.0268
# Epoch 163: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 10ms/step - loss: 1828.3091 - mean_squared_error: 1828.3091 - val_loss: 0.1171 - val_mean_squared_error: 0.1171
# Epoch 164/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0269 - mean_squared_error: 0.0269
# Epoch 164: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 12ms/step - loss: 1828.0364 - mean_squared_error: 1828.0364 - val_loss: 0.1182 - val_mean_squared_error: 0.1182
# Epoch 165/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0271 - mean_squared_error: 0.0271
# Epoch 165: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 11ms/step - loss: 1827.7593 - mean_squared_error: 1827.7593 - val_loss: 0.1192 - val_mean_squared_error: 0.1192
# Epoch 166/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0273 - mean_squared_error: 0.0273
# Epoch 166: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 9ms/step - loss: 1827.4797 - mean_squared_error: 1827.4797 - val_loss: 0.1204 - val_mean_squared_error: 0.1204
# Epoch 167/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0274 - mean_squared_error: 0.0274
# Epoch 167: val_mean_squared_error did not improve from 0.08522
# 5/5 [==============================] - 0s 12ms/step - loss: 1827.2025 - mean_squared_error: 1827.2025 - val_loss: 0.1215 - val_mean_squared_error: 0.1215
# Epoch 167: early stopping

# %%
import numpy as np
import tensorflow as tf

class CombinedMetricEarlyStopping(tf.keras.callbacks.Callback):
    def __init__(self, filepath, patience=50, verbose=1):
        super(CombinedMetricEarlyStopping, self).__init__()
        self.filepath = filepath
        self.patience = patience
        self.verbose = verbose
        self.best_combined_score = np.inf  # 最优综合分数
        self.best_epoch = -1
        self.no_improvement_count = 0  # 未改善的轮数

    def on_epoch_end(self, epoch, logs=None):
        # 获取训练集和验证集的 MSE
        train_mse = logs.get('mean_squared_error')  # 假设模型有 MSE 指标
        val_mse = logs.get('val_mean_squared_error')

        # 定义综合评分规则（训练 MSE + 验证 MSE）
        combined_score = train_mse + val_mse

        # 如果综合评分改善
        if combined_score < self.best_combined_score:
            self.best_combined_score = combined_score
            self.best_epoch = epoch
            self.no_improvement_count = 0  # 重置未改善计数器

            # 保存模型
            self.model.save(self.filepath)
            if self.verbose > 0:
                print(f"Epoch {epoch + 1}: Combined score improved to {combined_score:.4f}. Saving model to {self.filepath}.")
        else:
            self.no_improvement_count += 1
            if self.verbose > 0:
                print(f"Epoch {epoch + 1}: Combined score did not improve from {self.best_combined_score:.4f}. "
                      f"No improvement count: {self.no_improvement_count}/{self.patience}.")

        # 如果未改善的轮数达到耐心值，停止训练
        if self.no_improvement_count >= self.patience:
            print(f"Early stopping triggered at epoch {epoch + 1}. Best combined score: {self.best_combined_score:.4f}.")
            self.model.stop_training = True

# 定义路径和早停回调
filepath = "c:/data/result/model/score/best_model.h5"
early_stopping = CombinedMetricEarlyStopping(filepath=filepath, patience=200, verbose=1)

# 开始训练
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=1200,  # 最大训练轮次
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 1: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 2/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 2: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 3/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 3: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 4/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 4: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 5/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 5: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 6/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 6: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 7/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 7: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 8/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 8: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 9/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 9: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 10/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 10: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 11/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 11: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 12/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 12: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 13/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 13: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 14/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 14: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 15/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 15: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 16/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 16: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 17/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 17: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 18/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 18: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 19/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 19: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 20/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 20: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 21/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 21: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 22/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 22: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 23/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 23: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 24/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 24: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 25/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 25: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 26/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 26: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 27/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 27: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 28/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 28: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 29/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 29: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 30/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 30: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 31/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 31: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 32/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 32: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 33/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 33: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 34/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 34: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 35/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 35: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 36/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 36: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 37/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 37: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 38/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 38: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 39/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083Epoch 39: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 40/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 40: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 41/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 41: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 42/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 42: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 43/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 43: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 44/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 44: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 45/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 45: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 46/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 46: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 47/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 47: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 48/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 48: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 49/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 49: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 50/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 50: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 51/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 51: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 52/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 52: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 53/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 53: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 54/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 54: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 55/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 55: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 56/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 56: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 57/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 57: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 58/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 58: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 59/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 59: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 60/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 60: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 61/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 61: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 62/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 62: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 63/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 63: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 64/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 64: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 65/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 65: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 66/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 66: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 67/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 67: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 68/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 68: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 69/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 69: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 70/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 70: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 71/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 71: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 72/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 72: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 73/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 73: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 74/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 74: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 75/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 75: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 76/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 76: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 77/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 77: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 78/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 78: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 79/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 79: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 80/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 80: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 81/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 81: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 82/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 82: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 83/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 83: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 84/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 84: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 85/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 85: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 86/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 86: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 87/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 87: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 88/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 88: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 89/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 89: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 90/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 90: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 91/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 91: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 92/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 92: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 93/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 93: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 94/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 94: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 95/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 95: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 96/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 96: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 97/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 97: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 98/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 98: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 99/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 99: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 100/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 100: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 101/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 101: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 102/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 102: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 103/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 103: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 104/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 104: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 105/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 105: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 106/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 106: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 107/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 107: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 108/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 108: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 109/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 109: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 110/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 110: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 111/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 111: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 112/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 112: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 113/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 113: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 114/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 114: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 115/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 115: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 116/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 116: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 117/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 117: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 118/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 118: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 119/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 119: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 120/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 120: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 121/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 121: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 122/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 122: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 123/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 123: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 124/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 124: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 125/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 125: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 126/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 126: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 127/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 127: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 128/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 128: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 129/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 129: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 130/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 130: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 131/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 131: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 132/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 132: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 133/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 133: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 134/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 134: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 135/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082Epoch 135: Combined score improved to 0.0146. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 136/1200
# ...
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1155/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1155: Combined score did not improve from 0.0145. No improvement count: 2/200.
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1156/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1156: Combined score did not improve from 0.0145. No improvement count: 3/200.
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1157/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1157: Combined score did not improve from 0.0145. No improvement count: 4/200.
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1158/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1158: Combined score did not improve from 0.0145. No improvement count: 5/200.
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1159/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1159: Combined score did not improve from 0.0145. No improvement count: 6/200.
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1160/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1160: Combined score did not improve from 0.0145. No improvement count: 7/200.
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1161/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1161: Combined score did not improve from 0.0145. No improvement count: 8/200.
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1162/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1162: Combined score did not improve from 0.0145. No improvement count: 9/200.
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1163/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1163: Combined score did not improve from 0.0145. No improvement count: 10/200.
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1164/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1164: Combined score did not improve from 0.0145. No improvement count: 11/200.
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1165/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1165: Combined score did not improve from 0.0145. No improvement count: 12/200.
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1166/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1166: Combined score did not improve from 0.0145. No improvement count: 13/200.
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1167/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1167: Combined score did not improve from 0.0145. No improvement count: 14/200.
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1168/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1168: Combined score did not improve from 0.0145. No improvement count: 15/200.
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1169/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1169: Combined score did not improve from 0.0145. No improvement count: 16/200.
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1170/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1170: Combined score did not improve from 0.0145. No improvement count: 17/200.
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1171/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1171: Combined score did not improve from 0.0145. No improvement count: 18/200.
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1172/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1172: Combined score did not improve from 0.0145. No improvement count: 19/200.
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1173/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1173: Combined score did not improve from 0.0145. No improvement count: 20/200.
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1174/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1174: Combined score did not improve from 0.0145. No improvement count: 21/200.
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1175/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1175: Combined score did not improve from 0.0145. No improvement count: 22/200.
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1176/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1176: Combined score did not improve from 0.0145. No improvement count: 23/200.
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1177/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1177: Combined score improved to 0.0145. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1178/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1178: Combined score improved to 0.0145. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1179/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1179: Combined score improved to 0.0145. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1180/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1180: Combined score improved to 0.0145. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1181/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1181: Combined score did not improve from 0.0145. No improvement count: 1/200.
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1182/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1182: Combined score did not improve from 0.0145. No improvement count: 2/200.
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1183/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1183: Combined score did not improve from 0.0145. No improvement count: 3/200.
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1184/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1184: Combined score improved to 0.0145. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1185/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1185: Combined score improved to 0.0145. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1186/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1186: Combined score did not improve from 0.0145. No improvement count: 1/200.
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1187/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1187: Combined score improved to 0.0145. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1188/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1188: Combined score did not improve from 0.0145. No improvement count: 1/200.
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1189/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1189: Combined score did not improve from 0.0145. No improvement count: 2/200.
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1190/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1190: Combined score improved to 0.0145. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1191/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1191: Combined score improved to 0.0145. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1192/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1192: Combined score did not improve from 0.0145. No improvement count: 1/200.
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1193/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1193: Combined score did not improve from 0.0145. No improvement count: 2/200.
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1194/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1194: Combined score improved to 0.0145. Saving model to c:/data/result/model/score/best_model.h5.
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1195/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1195: Combined score did not improve from 0.0145. No improvement count: 1/200.
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1196/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1196: Combined score did not improve from 0.0145. No improvement count: 2/200.
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1197/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1197: Combined score did not improve from 0.0145. No improvement count: 3/200.
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1198/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1198: Combined score did not improve from 0.0145. No improvement count: 4/200.
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1199/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1199: Combined score did not improve from 0.0145. No improvement count: 5/200.
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 1200/1200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0081 - mean_squared_error: 0.0081Epoch 1200: Combined score did not improve from 0.0145. No improvement count: 6/200.
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
